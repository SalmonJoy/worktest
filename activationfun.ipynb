# %%
import math
import matplotlib.pyplot as plt

# %%
def sigmoidfun(i):
    return 1/(1+math.exp(-i))
# Out:
# 0.9933071490757153

# %%
xval=[]
yval=[]
for i in range(-6,6):
    xval.append(i)
    yval.append(sigmoidfun(i))

plt.plot(xval,yval)
